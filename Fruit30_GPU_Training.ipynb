# %%
import tensorflow as tf

print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import zipfile

with zipfile.ZipFile('Fruit30_Split.zip', 'r') as zip_ref:
    zip_ref.extractall('/content')

# %%
import os

print(os.listdir('/content'))
# Out:
# ['.config', 'Fruit30_Split.zip', '.ipynb_checkpoints', 'Fruit30_Split', 'sample_data']

# %%
print(os.listdir('/content/Fruit30_Split'))
# Out:
# ['test', 'val', 'train']

# %%
import tensorflow as tf

train_path = "/content/Fruit30_Split/train"
valid_path = "/content/Fruit30_Split/val"
test_path = "/content/Fruit30_Split/test"

train = tf.keras.utils.image_dataset_from_directory(
    train_path,
    image_size=(224, 224),
    batch_size=32
)

valid = tf.keras.utils.image_dataset_from_directory(
    valid_path,
    image_size=(224, 224),
    batch_size=32
)

test = tf.keras.utils.image_dataset_from_directory(
    test_path,
    image_size=(224, 224),
    batch_size=32
)
# Out:
# Found 21322 files belonging to 30 classes.
# Found 4559 files belonging to 30 classes.
# Found 4600 files belonging to 30 classes.

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import RandomFlip, RandomRotation, RandomZoom

data_augmentation = Sequential([
    RandomFlip("horizontal"),
    RandomRotation(0.1),
    RandomZoom(0.1)
])

# %%
from tensorflow.keras.layers import Rescaling

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import (
    Conv2D,
    MaxPooling2D,
    Flatten,
    Dense,
    Rescaling
)

fruit30_model_v6 = Sequential([

    Rescaling(1./255),

    data_augmentation,

    Conv2D(
        32,
        (3,3),
        activation="relu",
        padding="same",
        input_shape=(224,224,3)
    ),

    MaxPooling2D((2,2)),

    Conv2D(
        64,
        (3,3),
        activation="relu",
        padding="same"
    ),

    MaxPooling2D((2,2)),

    Conv2D(
        128,
        (3,3),
        activation="relu",
        padding="same"
    ),

    MaxPooling2D((2,2)),

    Flatten(),

    Dense(
        128,
        activation="relu"
    ),

    Dense(
        30,
        activation="softmax"
    )
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
fruit30_model_v6.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
fruit30_model_v6.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential (Sequential)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ ?                      │   0 (unbuilt) │
# ...

# %%
fruit30_model_v6.build((None, 224, 224, 3))

# %%
fruit30_model_v6.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential (Sequential)         │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 112, 112, 64)   │        18,496 │
# ...

# %%
history = fruit30_model_v6.fit(
    train,
    validation_data=valid,
    epochs=5
)
# Out:
# Epoch 1/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 51s 66ms/step - accuracy: 0.2457 - loss: 2.5584 - val_accuracy: 0.3402 - val_loss: 2.2710
# Epoch 2/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 44s 66ms/step - accuracy: 0.4061 - loss: 2.0065 - val_accuracy: 0.4251 - val_loss: 1.9974
# Epoch 3/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 44s 66ms/step - accuracy: 0.4697 - loss: 1.7822 - val_accuracy: 0.4747 - val_loss: 1.8445
# Epoch 4/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 81s 65ms/step - accuracy: 0.5224 - loss: 1.6085 - val_accuracy: 0.5302 - val_loss: 1.5989
# Epoch 5/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 44s 65ms/step - accuracy: 0.5586 - loss: 1.4756 - val_accuracy: 0.5569 - val_loss: 1.5447

# %%
test_loss, test_acc = fruit30_model_v6.evaluate(test)

print("Test Accuracy:", test_acc)
# Out:
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.5520 - loss: 1.5572
# Test Accuracy: 0.5519565343856812

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense

# %%
base_model = MobileNetV2(
    weights='imagenet',
    include_top=False,
    input_shape=(224, 224, 3)
)

base_model.trainable = False
# Out:
# ...
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
print(base_model.trainable)
# Out:
# False

# %%
transfer_model = Sequential([
    base_model,

    GlobalAveragePooling2D(),

    Dense(
        128,
        activation="relu"
    ),

    Dense(
        30,
        activation="softmax"
    )
])

# %%
transfer_model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
transfer_model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 30)             │         3,870 │
# ...

# %%
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input

# %%
train_mobilenet = train.map(
    lambda x, y: (preprocess_input(x), y)
)

valid_mobilenet = valid.map(
    lambda x, y: (preprocess_input(x), y)
)

test_mobilenet = test.map(
    lambda x, y: (preprocess_input(x), y)
)

# %%
history_transfer = transfer_model.fit(
    train_mobilenet,
    validation_data=valid_mobilenet,
    epochs=5
)
# Out:
# Epoch 1/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 77s 89ms/step - accuracy: 0.7705 - loss: 0.7874 - val_accuracy: 0.8467 - val_loss: 0.5113
# Epoch 2/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 36s 54ms/step - accuracy: 0.8799 - loss: 0.3948 - val_accuracy: 0.8598 - val_loss: 0.4669
# Epoch 3/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 31s 46ms/step - accuracy: 0.9134 - loss: 0.2871 - val_accuracy: 0.8693 - val_loss: 0.4451
# Epoch 4/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 42s 47ms/step - accuracy: 0.9323 - loss: 0.2172 - val_accuracy: 0.8684 - val_loss: 0.4566
# Epoch 5/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 30s 45ms/step - accuracy: 0.9486 - loss: 0.1674 - val_accuracy: 0.8769 - val_loss: 0.4565

# %%
test_loss, test_acc = transfer_model.evaluate(test_mobilenet)

print("Test Accuracy:", test_acc)
# Out:
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 17s 119ms/step - accuracy: 0.8754 - loss: 0.4576
# Test Accuracy: 0.8754347562789917

# %%
base_model.trainable = True

for layer in base_model.layers[:-30]:
    layer.trainable = False

# %%
print("Total layers:", len(base_model.layers))

trainable_count = 0

for layer in base_model.layers:
    if layer.trainable:
        trainable_count += 1

print("Trainable layers:", trainable_count)
# Out:
# Total layers: 154
# Trainable layers: 30

# %%
from tensorflow.keras.optimizers import Adam

transfer_model.compile(
    optimizer=Adam(learning_rate=0.00001),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
from tensorflow.keras.optimizers import Adam

transfer_model.compile(
    optimizer=Adam(learning_rate=1e-5),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
history_finetune = transfer_model.fit(
    train_mobilenet,
    validation_data=valid_mobilenet,
    epochs=5
)
# Out:
# Epoch 1/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 67s 74ms/step - accuracy: 0.8154 - loss: 0.6416 - val_accuracy: 0.8710 - val_loss: 0.4703
# Epoch 2/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 38s 57ms/step - accuracy: 0.8921 - loss: 0.3384 - val_accuracy: 0.8758 - val_loss: 0.4493
# Epoch 3/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 38s 57ms/step - accuracy: 0.9167 - loss: 0.2528 - val_accuracy: 0.8772 - val_loss: 0.4354
# Epoch 4/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 34s 51ms/step - accuracy: 0.9362 - loss: 0.1911 - val_accuracy: 0.8805 - val_loss: 0.4275
# Epoch 5/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.9498 - loss: 0.1555 - val_accuracy: 0.8848 - val_loss: 0.4160

# %%
test_loss, test_acc = transfer_model.evaluate(test_mobilenet)

print("Test Accuracy:", test_acc)
# Out:
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 9s 65ms/step - accuracy: 0.8802 - loss: 0.4449
# Test Accuracy: 0.8802173733711243

# %%
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Sequential

# %%
resnet_base = ResNet50(
    weights="imagenet",
    include_top=False,
    input_shape=(224,224,3)
)

resnet_base.trainable = False
# Out:
# ...
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
resnet_model = Sequential([
    resnet_base,

    GlobalAveragePooling2D(),

    Dense(
        128,
        activation="relu"
    ),

    Dense(
        30,
        activation="softmax"
    )
])

# %%
resnet_model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
resnet_model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)           │ (None, 7, 7, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 30)             │         3,870 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
# ...

# %%
from tensorflow.keras.applications.resnet50 import preprocess_input

# %%
train_resnet = train.map(
    lambda x, y: (preprocess_input(x), y)
)

valid_resnet = valid.map(
    lambda x, y: (preprocess_input(x), y)
)

test_resnet = test.map(
    lambda x, y: (preprocess_input(x), y)
)

# %%
history_resnet = resnet_model.fit(
    train_resnet,
    validation_data=valid_resnet,
    epochs=5
)
# Out:
# Epoch 1/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 104s 137ms/step - accuracy: 0.7951 - loss: 0.7033 - val_accuracy: 0.8723 - val_loss: 0.4263
# Epoch 2/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 124s 118ms/step - accuracy: 0.9047 - loss: 0.3080 - val_accuracy: 0.8855 - val_loss: 0.3952
# Epoch 3/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 78s 117ms/step - accuracy: 0.9361 - loss: 0.2049 - val_accuracy: 0.8965 - val_loss: 0.3714
# Epoch 4/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 85s 127ms/step - accuracy: 0.9569 - loss: 0.1392 - val_accuracy: 0.8936 - val_loss: 0.3918
# Epoch 5/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 78s 117ms/step - accuracy: 0.9657 - loss: 0.1094 - val_accuracy: 0.8875 - val_loss: 0.4380

# %%
test_loss, test_acc = resnet_model.evaluate(test_resnet)

print("Test Accuracy:", test_acc)
# Out:
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 18s 124ms/step - accuracy: 0.8867 - loss: 0.4544
# Test Accuracy: 0.8867391347885132

# %%
resnet_base.trainable = True

# %%
for layer in resnet_base.layers[:-30]:
    layer.trainable = False

# %%
print("Total layers:", len(resnet_base.layers))

trainable_count = 0

for layer in resnet_base.layers:
    if layer.trainable:
        trainable_count += 1

print("Trainable layers:", trainable_count)
# Out:
# Total layers: 175
# Trainable layers: 30

# %%
from tensorflow.keras.optimizers import Adam

resnet_model.compile(
    optimizer=Adam(learning_rate=1e-5),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
history_resnet_finetune = resnet_model.fit(
    train_resnet,
    validation_data=valid_resnet,
    epochs=5
)
# Out:
# Epoch 1/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 139s 174ms/step - accuracy: 0.5401 - loss: 1.8633 - val_accuracy: 0.8046 - val_loss: 0.7561
# Epoch 2/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 108s 162ms/step - accuracy: 0.8512 - loss: 0.5985 - val_accuracy: 0.8739 - val_loss: 0.4492
# Epoch 3/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 102s 153ms/step - accuracy: 0.9128 - loss: 0.3421 - val_accuracy: 0.9011 - val_loss: 0.3549
# Epoch 4/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 101s 152ms/step - accuracy: 0.9494 - loss: 0.2090 - val_accuracy: 0.9101 - val_loss: 0.3172
# Epoch 5/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 101s 151ms/step - accuracy: 0.9723 - loss: 0.1300 - val_accuracy: 0.9125 - val_loss: 0.2943

# %%
test_loss, test_acc = resnet_model.evaluate(test_resnet)

print("Test Accuracy:", test_acc)
# Out:
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 19s 128ms/step - accuracy: 0.9207 - loss: 0.3086
# Test Accuracy: 0.9206521511077881

# %%
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Sequential

# %%
efficientnet_base = EfficientNetB0(
    weights="imagenet",
    include_top=False,
    input_shape=(224,224,3)
)

efficientnet_base.trainable = False
# Out:
# ...
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
efficientnet_model = Sequential([
    efficientnet_base,

    GlobalAveragePooling2D(),

    Dense(
        128,
        activation="relu"
    ),

    Dense(
        30,
        activation="softmax"
    )
])

# %%
efficientnet_model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
efficientnet_model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ efficientnetb0 (Functional)     │ (None, 7, 7, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_2      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 128)            │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 30)             │         3,870 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
# ...

# %%
history_efficientnet = efficientnet_model.fit(
    train,
    validation_data=valid,
    epochs=5
)
# Out:
# Epoch 1/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 76s 85ms/step - accuracy: 0.8119 - loss: 0.6665 - val_accuracy: 0.8886 - val_loss: 0.3701
# Epoch 2/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 33s 49ms/step - accuracy: 0.9082 - loss: 0.3060 - val_accuracy: 0.9030 - val_loss: 0.3226
# Epoch 3/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 32s 49ms/step - accuracy: 0.9319 - loss: 0.2277 - val_accuracy: 0.9074 - val_loss: 0.3091
# Epoch 4/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 37s 56ms/step - accuracy: 0.9457 - loss: 0.1811 - val_accuracy: 0.9101 - val_loss: 0.3002
# Epoch 5/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 33s 50ms/step - accuracy: 0.9550 - loss: 0.1486 - val_accuracy: 0.9169 - val_loss: 0.2897

# %%
test_loss, test_acc = efficientnet_model.evaluate(test)

print("Test Accuracy:", test_acc)
# Out:
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 28s 103ms/step - accuracy: 0.0248 - loss: 3.4859
# Test Accuracy: 0.024782609194517136

# %%
efficientnet_base.trainable = True

# %%
for layer in efficientnet_base.layers[:-30]:
    layer.trainable = False

# %%
print("Total layers:", len(efficientnet_base.layers))

trainable_count = 0

for layer in efficientnet_base.layers:
    if layer.trainable:
        trainable_count += 1

print("Trainable layers:", trainable_count)
# Out:
# Total layers: 238
# Trainable layers: 30

# %%
from tensorflow.keras.optimizers import Adam

efficientnet_model.compile(
    optimizer=Adam(learning_rate=1e-5),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
history_efficientnet_finetune = efficientnet_model.fit(
    train,
    validation_data=valid,
    epochs=5
)
# Out:
# Epoch 1/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 88s 89ms/step - accuracy: 0.8510 - loss: 0.5174 - val_accuracy: 0.8623 - val_loss: 0.4562
# Epoch 2/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 34s 51ms/step - accuracy: 0.9036 - loss: 0.3367 - val_accuracy: 0.8853 - val_loss: 0.3775
# Epoch 3/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 35s 52ms/step - accuracy: 0.9245 - loss: 0.2695 - val_accuracy: 0.8965 - val_loss: 0.3396
# Epoch 4/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 35s 53ms/step - accuracy: 0.9330 - loss: 0.2322 - val_accuracy: 0.9044 - val_loss: 0.3173
# Epoch 5/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.9431 - loss: 0.2038 - val_accuracy: 0.9094 - val_loss: 0.3009

# %%
test_loss, test_acc = efficientnet_model.evaluate(test)

print("Test Accuracy:", test_acc)
# Out:
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 9s 64ms/step - accuracy: 0.9078 - loss: 0.3200
# Test Accuracy: 0.9078260660171509

# %%
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Sequential

# %%
densenet_base = DenseNet121(
    weights="imagenet",
    include_top=False,
    input_shape=(224,224,3)
)

densenet_base.trainable = False
# Out:
# ...
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
densenet_model = Sequential([
    densenet_base,

    GlobalAveragePooling2D(),

    Dense(
        128,
        activation="relu"
    ),

    Dense(
        30,
        activation="softmax"
    )
])

# %%
densenet_model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
densenet_model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ densenet121 (Functional)        │ (None, 7, 7, 1024)     │     7,037,504 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_3      │ (None, 1024)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 128)            │       131,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 30)             │         3,870 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
# ...

# %%
history_densenet = densenet_model.fit(
    train,
    validation_data=valid,
    epochs=5
)
# Out:
# Epoch 1/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 124s 146ms/step - accuracy: 0.2584 - loss: 2.8629 - val_accuracy: 0.3803 - val_loss: 2.1408
# Epoch 2/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 92s 93ms/step - accuracy: 0.4077 - loss: 2.0288 - val_accuracy: 0.4606 - val_loss: 1.8567
# Epoch 3/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 62s 93ms/step - accuracy: 0.4706 - loss: 1.8126 - val_accuracy: 0.4801 - val_loss: 1.7974
# Epoch 4/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 62s 93ms/step - accuracy: 0.5026 - loss: 1.6812 - val_accuracy: 0.4981 - val_loss: 1.7437
# Epoch 5/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 62s 93ms/step - accuracy: 0.5307 - loss: 1.5903 - val_accuracy: 0.5227 - val_loss: 1.6332

# %%
from tensorflow.keras.applications.densenet import preprocess_input

train_densenet = train.map(
    lambda x, y: (preprocess_input(x), y)
)

valid_densenet = valid.map(
    lambda x, y: (preprocess_input(x), y)
)

test_densenet = test.map(
    lambda x, y: (preprocess_input(x), y)
)

# %%
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Sequential

densenet_base = DenseNet121(
    weights="imagenet",
    include_top=False,
    input_shape=(224,224,3)
)

densenet_base.trainable = False

densenet_model = Sequential([
    densenet_base,
    GlobalAveragePooling2D(),
    Dense(128, activation="relu"),
    Dense(30, activation="softmax")
])

# %%
densenet_model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
history_densenet = densenet_model.fit(
    train_densenet,
    validation_data=valid_densenet,
    epochs=5
)
# Out:
# Epoch 1/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 120s 146ms/step - accuracy: 0.7687 - loss: 0.8095 - val_accuracy: 0.8605 - val_loss: 0.4722
# Epoch 2/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 67s 100ms/step - accuracy: 0.8805 - loss: 0.3947 - val_accuracy: 0.8769 - val_loss: 0.4281
# Epoch 3/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 66s 99ms/step - accuracy: 0.9045 - loss: 0.3144 - val_accuracy: 0.8851 - val_loss: 0.3772
# Epoch 4/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 83s 101ms/step - accuracy: 0.9206 - loss: 0.2647 - val_accuracy: 0.8945 - val_loss: 0.3673
# Epoch 5/5
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 83s 102ms/step - accuracy: 0.9349 - loss: 0.2173 - val_accuracy: 0.8973 - val_loss: 0.3550

# %%
test_loss, test_acc = densenet_model.evaluate(test_densenet)

print("Test Accuracy:", test_acc)
# Out:
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 25s 170ms/step - accuracy: 0.8867 - loss: 0.3964
# Test Accuracy: 0.8867391347885132

# %%
# !pip install -q transformers

# %%
from transformers import ViTModel
from tensorflow.keras.layers import Dense, GlobalAveragePooling1D
from tensorflow.keras.models import Sequential

# %%
vit_base = ViTModel.from_pretrained(
    "google/vit-base-patch16-224"
)

print(type(vit_base))
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:112: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/69.7k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/198 [00:00<?, ?it/s]
# [transformers] ViTModel LOAD REPORT from: google/vit-base-patch16-224
# Key                 | Status     |
# ...

# %%
# !pip install -q vit-keras
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.7/44.7 kB 2.2 MB/s eta 0:00:00

# %%
import torch

print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# 2.11.0+cu128
# True

# %%
from transformers import ViTModel

vit_base = ViTModel.from_pretrained(
    "google/vit-base-patch16-224"
)

print("Loaded successfully")
# Out:
# Loading weights:   0%|          | 0/198 [00:00<?, ?it/s]
# [transformers] ViTModel LOAD REPORT from: google/vit-base-patch16-224
# Key                 | Status     |
# --------------------+------------+-
# classifier.weight   | UNEXPECTED |
# classifier.bias     | UNEXPECTED |
# pooler.dense.bias   | MISSING    |
# pooler.dense.weight | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Loaded successfully

# %%
from transformers import AutoImageProcessor

processor = AutoImageProcessor.from_pretrained(
    "google/vit-base-patch16-224"
)

print("Processor loaded")
# Out:
# preprocessor_config.json:   0%|          | 0.00/160 [00:00<?, ?B/s]
# Processor loaded

# %%
import os

print(os.listdir("Fruit30_Split"))
# Out:
# ['test', 'val', 'train']

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
from transformers import AutoImageProcessor, ViTForImageClassification

# %%
processor = AutoImageProcessor.from_pretrained(
    "google/vit-base-patch16-224"
)

# %%
from PIL import Image

class ViTDataset(torch.utils.data.Dataset):

    def __init__(self, dataset, processor):
        self.dataset = dataset
        self.processor = processor

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        image, label = self.dataset[idx]

        encoding = self.processor(
            images=image,
            return_tensors="pt"
        )

        pixel_values = encoding["pixel_values"].squeeze()

        return pixel_values, label

# %%
train_dataset_raw = ImageFolder(
    "Fruit30_Split/train"
)

val_dataset_raw = ImageFolder(
    "Fruit30_Split/val"
)

test_dataset_raw = ImageFolder(
    "Fruit30_Split/test"
)

# %%
train_dataset = ViTDataset(
    train_dataset_raw,
    processor
)

val_dataset = ViTDataset(
    val_dataset_raw,
    processor
)

test_dataset = ViTDataset(
    test_dataset_raw,
    processor
)

# %%
train_loader = DataLoader(
    train_dataset,
    batch_size=32,
    shuffle=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=32,
    shuffle=False
)

test_loader = DataLoader(
    test_dataset,
    batch_size=32,
    shuffle=False
)

# %%
model = ViTForImageClassification.from_pretrained(
    "google/vit-base-patch16-224",
    num_labels=30,
    ignore_mismatched_sizes=True
)
# Out:
# [transformers] You passed `num_labels=30` which is incompatible to the `id2label` map of length `1000`.
# Loading weights:   0%|          | 0/200 [00:00<?, ?it/s]
# [transformers] ViTForImageClassification LOAD REPORT from: google/vit-base-patch16-224
# Key               | Status   |
# ------------------+----------+-------------------------------------------------------------------------------------------
# classifier.bias   | MISMATCH | Reinit due to size mismatch - ckpt: torch.Size([1000]) vs model:torch.Size([30])
# classifier.weight | MISMATCH | Reinit due to size mismatch - ckpt: torch.Size([1000, 768]) vs model:torch.Size([30, 768])
#
# Notes:
# - MISMATCH:	ckpt weights were loaded, but they did not match the original empty weight shapes.

# %%
for param in model.vit.parameters():
    param.requires_grad = False

# %%
device = torch.device(
    "cuda" if torch.cuda.is_available() else "cpu"
)

model.to(device)

print(device)
# Out:
# cuda

# %%
optimizer = torch.optim.Adam(
    model.parameters(),
    lr=1e-4
)

criterion = nn.CrossEntropyLoss()

# %%
model.train()

running_loss = 0
correct = 0
total = 0

for pixel_values, labels in train_loader:

    pixel_values = pixel_values.to(device)
    labels = labels.to(device)

    optimizer.zero_grad()

    outputs = model(
        pixel_values=pixel_values,
        labels=labels
    )

    loss = outputs.loss

    loss.backward()

    optimizer.step()

    running_loss += loss.item()

    preds = outputs.logits.argmax(dim=1)

    total += labels.size(0)

    correct += (preds == labels).sum().item()

train_acc = 100 * correct / total

print("Train Accuracy:", train_acc)
# Out:
# Train Accuracy: 86.49751430447425

# %%
num_epochs = 4   # because you've already completed Epoch 1

for epoch in range(num_epochs):

    model.train()

    train_loss = 0
    train_correct = 0
    train_total = 0

    for pixel_values, labels in train_loader:

        pixel_values = pixel_values.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        outputs = model(
            pixel_values=pixel_values,
            labels=labels
        )

        loss = outputs.loss

        loss.backward()

        optimizer.step()

        train_loss += loss.item()

        preds = outputs.logits.argmax(dim=1)

        train_total += labels.size(0)
        train_correct += (preds == labels).sum().item()

    train_acc = 100 * train_correct / train_total
    train_loss = train_loss / len(train_loader)

    model.eval()

    val_loss = 0
    val_correct = 0
    val_total = 0

    with torch.no_grad():

        for pixel_values, labels in val_loader:

            pixel_values = pixel_values.to(device)
            labels = labels.to(device)

            outputs = model(
                pixel_values=pixel_values,
                labels=labels
            )

            loss = outputs.loss

            val_loss += loss.item()

            preds = outputs.logits.argmax(dim=1)

            val_total += labels.size(0)
            val_correct += (preds == labels).sum().item()

    val_acc = 100 * val_correct / val_total
    val_loss = val_loss / len(val_loader)

    print(f"\nEpoch {epoch+2}/5")
    print(
        f"Train Loss: {train_loss:.4f} | "
        f"Train Accuracy: {train_acc:.2f}%"
    )
    print(
        f"Validation Loss: {val_loss:.4f} | "
        f"Validation Accuracy: {val_acc:.2f}%"
    )
# Out:
# Epoch 2/5
# Train Loss: 0.2243 | Train Accuracy: 95.68%
# Validation Loss: 0.1774 | Validation Accuracy: 96.14%
#
# Epoch 3/5
# Train Loss: 0.1683 | Train Accuracy: 96.24%
# Validation Loss: 0.1491 | Validation Accuracy: 96.64%
#
# Epoch 4/5
# Train Loss: 0.1433 | Train Accuracy: 96.73%
# Validation Loss: 0.1352 | Validation Accuracy: 96.71%
#
# Epoch 5/5
# Train Loss: 0.1273 | Train Accuracy: 97.04%
# Validation Loss: 0.1262 | Validation Accuracy: 96.86%

# %%
model.eval()

test_correct = 0
test_total = 0

with torch.no_grad():

    for pixel_values, labels in test_loader:

        pixel_values = pixel_values.to(device)
        labels = labels.to(device)

        outputs = model(pixel_values=pixel_values)

        preds = outputs.logits.argmax(dim=1)

        test_total += labels.size(0)
        test_correct += (preds == labels).sum().item()

test_acc = 100 * test_correct / test_total

print(f"Test Accuracy: {test_acc:.2f}%")
# Out:
# Test Accuracy: 96.70%

# %%
print(model)
# Out:
# ViTForImageClassification(
#   (vit): ViTModel(
#     (embeddings): ViTEmbeddings(
#       (patch_embeddings): ViTPatchEmbeddings(
#         (projection): Conv2d(3, 768, kernel_size=(16, 16), stride=(16, 16))
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (layers): ModuleList(
#       (0-11): 12 x ViTLayer(
#         (attention): ViTAttention(
#           (q_proj): Linear(in_features=768, out_features=768, bias=True)
#           (k_proj): Linear(in_features=768, out_features=768, bias=True)
#           (v_proj): Linear(in_features=768, out_features=768, bias=True)
#           (o_proj): Linear(in_features=768, out_features=768, bias=True)
#         )
#         (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (mlp): ViTMLP(
#           (activation_fn): GELUActivation()
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
# ...

# %%
for param in model.parameters():
    param.requires_grad = False

# %%
# Last 2 transformer blocks

for param in model.vit.layers[-2:].parameters():
    param.requires_grad = True

# Final layernorm

for param in model.vit.layernorm.parameters():
    param.requires_grad = True

# Classification head

for param in model.classifier.parameters():
    param.requires_grad = True

# %%
trainable_params = sum(
    p.numel()
    for p in model.parameters()
    if p.requires_grad
)

print(f"Trainable Params: {trainable_params:,}")
# Out:
# Trainable Params: 14,200,350

# %%
import torch
import torch.optim as optim
import torch.nn as nn

# Loss Function
criterion = nn.CrossEntropyLoss()

# Optimizer
optimizer = optim.AdamW(
    filter(lambda p: p.requires_grad, model.parameters()),
    lr=1e-5,
    weight_decay=1e-4
)

# Scheduler
scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='max',
    factor=0.5,
    patience=2
)

# =========================
# TRAIN FOR 1 EPOCH ONLY
# =========================

num_epochs = 1

for epoch in range(num_epochs):

    # TRAINING
    model.train()

    running_loss = 0
    correct = 0
    total = 0

    for images, labels in train_loader:

        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        outputs = model(images)

        logits = outputs.logits

        loss = criterion(logits, labels)

        loss.backward()

        optimizer.step()

        running_loss += loss.item()

        _, predicted = torch.max(logits, 1)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total

    # VALIDATION
    model.eval()

    val_loss = 0
    correct = 0
    total = 0

    with torch.no_grad():

        for images, labels in val_loader:

            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)

            logits = outputs.logits

            loss = criterion(logits, labels)

            val_loss += loss.item()

            _, predicted = torch.max(logits, 1)

            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    val_loss /= len(val_loader)
    val_acc = 100 * correct / total

    scheduler.step(val_acc)

    print(f"\nEpoch {epoch+1}/{num_epochs}")
    print(f"Train Loss: {train_loss:.4f} | Train Accuracy: {train_acc:.2f}%")
    print(f"Validation Loss: {val_loss:.4f} | Validation Accuracy: {val_acc:.2f}%")

# =========================
# TEST ACCURACY
# =========================

model.eval()

correct = 0
total = 0

with torch.no_grad():

    for images, labels in test_loader:

        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)

        logits = outputs.logits

        _, predicted = torch.max(logits, 1)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()

test_acc = 100 * correct / total

print(f"\nTest Accuracy: {test_acc:.2f}%")
# Out:
# Epoch 1/1
# Train Loss: 0.1520 | Train Accuracy: 97.46%
# Validation Loss: 0.1312 | Validation Accuracy: 97.48%
#
# Test Accuracy: 96.63%

# %%
num_epochs = 4

for epoch in range(num_epochs):

    model.train()

    running_loss = 0
    correct = 0
    total = 0

    for images, labels in train_loader:

        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        outputs = model(images)

        logits = outputs.logits

        loss = criterion(logits, labels)

        loss.backward()

        optimizer.step()

        running_loss += loss.item()

        _, predicted = torch.max(logits, 1)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total

    model.eval()

    val_loss = 0
    correct = 0
    total = 0

    with torch.no_grad():

        for images, labels in val_loader:

            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)

            logits = outputs.logits

            loss = criterion(logits, labels)

            val_loss += loss.item()

            _, predicted = torch.max(logits, 1)

            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    val_loss /= len(val_loader)
    val_acc = 100 * correct / total

    scheduler.step(val_acc)

    print(f"\nEpoch {epoch+2}/5")
    print(f"Train Loss: {train_loss:.4f} | Train Accuracy: {train_acc:.2f}%")
    print(f"Validation Loss: {val_loss:.4f} | Validation Accuracy: {val_acc:.2f}%")
# Out:
# Epoch 2/5
# Train Loss: 0.0964 | Train Accuracy: 97.95%
# Validation Loss: 0.1111 | Validation Accuracy: 97.67%
#
# Epoch 3/5
# Train Loss: 0.0766 | Train Accuracy: 98.33%
# Validation Loss: 0.1046 | Validation Accuracy: 97.61%
#
# Epoch 4/5
# Train Loss: 0.0633 | Train Accuracy: 98.62%
# Validation Loss: 0.0985 | Validation Accuracy: 97.74%
#
# Epoch 5/5
# Train Loss: 0.0530 | Train Accuracy: 98.91%
# Validation Loss: 0.0965 | Validation Accuracy: 97.70%

# %%
model.eval()

correct = 0
total = 0

with torch.no_grad():

    for images, labels in test_loader:

        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)

        logits = outputs.logits

        _, predicted = torch.max(logits, 1)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()

test_acc = 100 * correct / total

print(f"\nTest Accuracy: {test_acc:.2f}%")
# Out:
# Test Accuracy: 96.98%

# %%
torch.save(
    model.state_dict(),
    "Fruit30_ViT_FineTuned.pth"
)

print("Fruit30 model saved")
# Out:
# Fruit30 model saved

# %%
dir(train_dataset)
# Out:
# ['__add__',
#  '__annotations__',
#  '__class__',
#  '__class_getitem__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__orig_bases__',
#  '__parameters__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'dataset',
#  'processor']

# %%
print(type(train_dataset.dataset))
# Out:
# <class 'torchvision.datasets.folder.ImageFolder'>

# %%
dir(train_dataset.dataset)
# Out:
# ['__add__',
#  '__annotations__',
#  '__class__',
#  '__class_getitem__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__orig_bases__',
#  '__parameters__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_format_transform_repr',
#  '_repr_indent',
#  'class_to_idx',
#  'classes',
#  'extensions',
#  'extra_repr',
#  'find_classes',
#  'imgs',
#  'loader',
#  'make_dataset',
#  'root',
#  'samples',
#  'target_transform',
#  'targets',
#  'transform',
#  'transforms']

# %%
print(train_dataset.dataset.__dict__.keys())
# Out:
# dict_keys(['root', 'transform', 'target_transform', 'transforms', 'loader', 'extensions', 'classes', 'class_to_idx', 'samples', 'targets', 'imgs'])

# %%
print(train_dataset.dataset.classes)
# Out:
# ['apple', 'apricot', 'avocado', 'banana', 'black berry', 'blueberry', 'cherry', 'coconut', 'custard apple', 'dragonfruit', 'grape', 'guava', 'jackfruit', 'jujube', 'kiwi', 'lychee', 'mango', 'muskmelon', 'orange', 'papaya', 'passion fruit', 'pear', 'pineapple', 'pomegranate', 'raspberry', 'strawberry', 'tomato', 'watermelon', 'white mulberry', 'yellow plum']

# %%
print(train_dataset.dataset.class_to_idx)
# Out:
# {'apple': 0, 'apricot': 1, 'avocado': 2, 'banana': 3, 'black berry': 4, 'blueberry': 5, 'cherry': 6, 'coconut': 7, 'custard apple': 8, 'dragonfruit': 9, 'grape': 10, 'guava': 11, 'jackfruit': 12, 'jujube': 13, 'kiwi': 14, 'lychee': 15, 'mango': 16, 'muskmelon': 17, 'orange': 18, 'papaya': 19, 'passion fruit': 20, 'pear': 21, 'pineapple': 22, 'pomegranate': 23, 'raspberry': 24, 'strawberry': 25, 'tomato': 26, 'watermelon': 27, 'white mulberry': 28, 'yellow plum': 29}

# %%
import transformers
print(transformers.__version__)
# Out:
# 5.10.2

# %%
from transformers import ViTForImageClassification

model.save_pretrained("Fruit30_Model")

print("Fruit30 HF Model Saved")
# Out:
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Fruit30 HF Model Saved
